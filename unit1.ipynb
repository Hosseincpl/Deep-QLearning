# %% [markdown]
# <a href="https://colab.research.google.com/github/Hosseincpl/Deep-QLearning/blob/main/unit1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install swig cmake
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cmake is already the newest version (3.16.3-1ubuntu1.20.04.1).
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 24 not upgraded.
# Need to get 1,086 kB of archives.
# After this operation, 5,413 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 swig4.0 amd64 4.0.1-5build1 [1,081 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 swig all 4.0.1-5build1 [5,528 B]
# Fetched 1,086 kB in 1s (2,095 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 122518 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.1-5build1_amd64.deb ...
# Unpacking swig4.0 (4.0.1-5build1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.1-5build1_all.deb ...
# Unpacking swig (4.0.1-5build1) ...
# Setting up swig4.0 (4.0.1-5build1) ...
# Setting up swig (4.0.1-5build1) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
# !pip install -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt
# Out:
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2784114 sha256=1b37981dc5ab061acca9d688f71076097dd1ec6cd5da9c5aca9c36e6f4dd2033
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: swig, farama-notifications, box2d-py, pygame, jax-jumpy, huggingface-hub, gymnasium, huggingface_sb3, stable-baselines3
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.3.0
#     Uninstalling pygame-2.3.0:
#       Successfully uninstalled pygame-2.3.0
# Successfully installed box2d-py-2.3.5 farama-notifications-0.0.4 gymnasium-0.28.1 huggingface-hub-0.14.1 huggingface_sb3-2.2.4 jax-jumpy-1.0.0 pygame-2.1.3 stable-baselines3-2.0.0a5 swig-4.1.1

# %%
# !sudo apt-get update
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:4 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [1,007 kB]
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Get:8 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,150 kB]
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Get:13 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2,668 kB]
# Hit:14 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Fetched 7,166 kB in 2s (4,216 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   freeglut3 libpython2-stdlib python2 python2-minimal
# Suggested packages:
#   python-tk python-numpy libgle3 python2-doc
# The following NEW packages will be installed:
#   freeglut3 libpython2-stdlib python-opengl python2 python2-minimal
# 0 upgraded, 5 newly installed, 0 to remove and 25 not upgraded.
# Need to get 621 kB of archives.
# After this operation, 6,059 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2-minimal amd64 2.7.17-2ubuntu4 [27.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libpython2-stdlib amd64 2.7.17-2ubuntu4 [7,072 B]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2 amd64 2.7.17-2ubuntu4 [26.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 freeglut3 amd64 2.8.1-3 [73.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/universe amd64 python-opengl all 3.1.0+dfsg-2build1 [486 kB]
# Fetched 621 kB in 0s (1,744 kB/s)
# Selecting previously unselected package python2-minimal.
# (Reading database ... 123269 files and directories currently installed.)
# Preparing to unpack .../python2-minimal_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2-minimal (2.7.17-2ubuntu4) ...
# Selecting previously unselected package libpython2-stdlib:amd64.
# Preparing to unpack .../libpython2-stdlib_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# Setting up python2-minimal (2.7.17-2ubuntu4) ...
# Selecting previously unselected package python2.
# (Reading database ... 123298 files and directories currently installed.)
# Preparing to unpack .../python2_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2 (2.7.17-2ubuntu4) ...
# Selecting previously unselected package freeglut3:amd64.
# Preparing to unpack .../freeglut3_2.8.1-3_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-3) ...
# Selecting previously unselected package python-opengl.
# Preparing to unpack .../python-opengl_3.1.0+dfsg-2build1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-2build1) ...
# Setting up freeglut3:amd64 (2.8.1-3) ...
# Setting up libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# Setting up python2 (2.7.17-2ubuntu4) ...
# Setting up python-opengl (3.1.0+dfsg-2build1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings
#   xfonts-utils xserver-common
# The following NEW packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings
#   xfonts-utils xserver-common xvfb
# 0 upgraded, 9 newly installed, 0 to remove and 25 not upgraded.
# Need to get 7,697 kB of archives.
# After this operation, 11.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 libfontenc1 amd64 1:1.1.4-0ubuntu1 [14.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 libxfont2 amd64 1:2.0.3-1 [91.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 libxkbfile1 amd64 1:1.1.0-1 [65.3 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 x11-xkb-utils amd64 7.7+5 [158 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu1 [573 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-utils amd64 1:7.7+6 [91.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 xserver-common all 2:1.20.13-1ubuntu1~20.04.8 [27.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 xvfb amd64 2:1.20.13-1ubuntu1~20.04.8 [780 kB]
# Fetched 7,697 kB in 0s (16.2 MB/s)
# Selecting previously unselected package libfontenc1:amd64.
# (Reading database ... 125688 files and directories currently installed.)
# Preparing to unpack .../0-libfontenc1_1%3a1.1.4-0ubuntu1_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../1-libxfont2_1%3a2.0.3-1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.3-1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../2-libxkbfile1_1%3a1.1.0-1_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../3-x11-xkb-utils_7.7+5_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../4-xfonts-encodings_1%3a1.0.5-0ubuntu1_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu1) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../5-xfonts-utils_1%3a7.7+6_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../6-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../7-xserver-common_2%3a1.20.13-1ubuntu1~20.04.8_all.deb ...
# Unpacking xserver-common (2:1.20.13-1ubuntu1~20.04.8) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../8-xvfb_2%3a1.20.13-1ubuntu1~20.04.8_amd64.deb ...
# Unpacking xvfb (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1) ...
# Setting up libxfont2:amd64 (1:2.0.3-1) ...
# Setting up x11-xkb-utils (7.7+5) ...
# Setting up xfonts-utils (1:7.7+6) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up xserver-common (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up xvfb (2:1.20.13-1ubuntu1~20.04.8) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0

# %%
import os
os.kill(os.getpid(), 9)

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
import gymnasium

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env

# %%
import gymnasium as gym

# First, we create our environment called LunarLander-v2
env = gym.make("LunarLander-v2")

# Then we reset this environment
observation, info = env.reset()

for _ in range(20):
  # Take a random action
  action = env.action_space.sample()
  print("Action taken:", action)

  # Do this action in the environment and get
  # next_state, reward, terminated, truncated and info
  observation, reward, terminated, truncated, info = env.step(action)
  
  # If the game is terminated (in our case we land, crashed) or truncated (timeout)
  if terminated or truncated:
      # Reset the environment
      print("Environment is reset")
      observation, info = env.reset()

env.close()
# Out:
# Action taken: 1
# Action taken: 2
# Action taken: 2
# Action taken: 1
# Action taken: 0
# Action taken: 2
# Action taken: 3
# Action taken: 2
# Action taken: 3
# Action taken: 1
# Action taken: 2
# Action taken: 0
# Action taken: 1
# Action taken: 3
# Action taken: 1
# Action taken: 1
# Action taken: 2
# Action taken: 1
# Action taken: 2
# Action taken: 3

# %%
# We create our environment with gym.make("")
env = gym.make("LunarLander-v2")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [-36.088905     5.851694    -3.4972606   -2.9523284    0.6054901
#    1.8329469    0.54640365   0.09802803]

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 3

# %%
# Create the environment
env = make_vec_env('LunarLander-v2', n_envs=16)

# %%
# We added some parameters to accelerate the training
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)
# Out:
# Using cuda device

# %%
# Train it for 1,000,000 timesteps
model.learn(total_timesteps=1000000)
# Save the model
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94       |
# |    ep_rew_mean     | -193     |
# | time/              |          |
# |    fps             | 1987     |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 16384    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 101          |
# |    ep_rew_mean          | -146         |
# | time/                   |              |
# |    fps                  | 1925         |
# |    iterations           | 2            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0046310485 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000509     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.78e+03     |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.00281     |
# |    value_loss           | 4.66e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.3        |
# |    ep_rew_mean          | -138        |
# | time/                   |             |
# |    fps                  | 1864        |
# |    iterations           | 3           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009863079 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.00364     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 622         |
# |    n_updates            | 8           |
# |    policy_gradient_loss | -0.00674    |
# |    value_loss           | 2e+03       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 97.2         |
# |    ep_rew_mean          | -121         |
# | time/                   |              |
# |    fps                  | 1820         |
# |    iterations           | 4            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0056121843 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.0132      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 956          |
# |    n_updates            | 12           |
# |    policy_gradient_loss | -0.00373     |
# |    value_loss           | 1.42e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 103        |
# |    ep_rew_mean          | -104       |
# | time/                   |            |
# |    fps                  | 1842       |
# |    iterations           | 5          |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.00842578 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | -0.000578  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 563        |
# |    n_updates            | 16         |
# |    policy_gradient_loss | -0.00643   |
# |    value_loss           | 858        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 115         |
# |    ep_rew_mean          | -85.7       |
# | time/                   |             |
# |    fps                  | 1789        |
# |    iterations           | 6           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010965871 |
# |    clip_fraction        | 0.0869      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -9.45e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 574         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00616    |
# |    value_loss           | 683         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 119          |
# |    ep_rew_mean          | -61.6        |
# | time/                   |              |
# |    fps                  | 1741         |
# |    iterations           | 7            |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0048608715 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.000125     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 400          |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.00267     |
# |    value_loss           | 572          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 122         |
# |    ep_rew_mean          | -52.4       |
# | time/                   |             |
# |    fps                  | 1705        |
# |    iterations           | 8           |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.008423938 |
# |    clip_fraction        | 0.0573      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | -0.00231    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 216         |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.0044     |
# |    value_loss           | 491         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 146          |
# |    ep_rew_mean          | -35.5        |
# | time/                   |              |
# |    fps                  | 1659         |
# |    iterations           | 9            |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0069486494 |
# |    clip_fraction        | 0.0299       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.000366     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 281          |
# |    n_updates            | 32           |
# |    policy_gradient_loss | -0.00271     |
# |    value_loss           | 518          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 159         |
# |    ep_rew_mean          | -34.4       |
# | time/                   |             |
# |    fps                  | 1570        |
# |    iterations           | 10          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.005134281 |
# |    clip_fraction        | 0.0376      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | -0.0015     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 237         |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.0024     |
# |    value_loss           | 514         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 228          |
# |    ep_rew_mean          | -26          |
# | time/                   |              |
# |    fps                  | 1452         |
# |    iterations           | 11           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0068963734 |
# |    clip_fraction        | 0.0716       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 5.06e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 581          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00408     |
# |    value_loss           | 697          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 271         |
# |    ep_rew_mean          | -13.2       |
# | time/                   |             |
# |    fps                  | 1389        |
# |    iterations           | 12          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.006551488 |
# |    clip_fraction        | 0.0544      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.0049      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 316         |
# |    n_updates            | 44          |
# |    policy_gradient_loss | -0.00436    |
# |    value_loss           | 436         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 305          |
# |    ep_rew_mean          | -5.67        |
# | time/                   |              |
# |    fps                  | 1309         |
# |    iterations           | 13           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0052873176 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.0639       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 230          |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.00251     |
# |    value_loss           | 508          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 339         |
# |    ep_rew_mean          | 7.68        |
# | time/                   |             |
# |    fps                  | 1265        |
# |    iterations           | 14          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.007106445 |
# |    clip_fraction        | 0.0252      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.293       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 98.9        |
# |    n_updates            | 52          |
# |    policy_gradient_loss | -0.00232    |
# |    value_loss           | 303         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 384          |
# |    ep_rew_mean          | 12.8         |
# | time/                   |              |
# |    fps                  | 1208         |
# |    iterations           | 15           |
# |    time_elapsed         | 203          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0050366293 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.537        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 229          |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00111     |
# |    value_loss           | 315          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 423          |
# |    ep_rew_mean          | 16.7         |
# | time/                   |              |
# |    fps                  | 1175         |
# |    iterations           | 16           |
# |    time_elapsed         | 222          |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0039298134 |
# |    clip_fraction        | 0.0223       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.71         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 82.5         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000913    |
# |    value_loss           | 212          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 515         |
# |    ep_rew_mean          | 28.8        |
# | time/                   |             |
# |    fps                  | 1140        |
# |    iterations           | 17          |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.005689168 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.767       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93.3        |
# |    n_updates            | 64          |
# |    policy_gradient_loss | -0.00285    |
# |    value_loss           | 215         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 540         |
# |    ep_rew_mean          | 34.1        |
# | time/                   |             |
# |    fps                  | 1104        |
# |    iterations           | 18          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.006972894 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62.4        |
# |    n_updates            | 68          |
# |    policy_gradient_loss | -0.00128    |
# |    value_loss           | 155         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 531         |
# |    ep_rew_mean          | 26.2        |
# | time/                   |             |
# |    fps                  | 1083        |
# |    iterations           | 19          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.003609872 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.8        |
# |    n_updates            | 72          |
# |    policy_gradient_loss | -0.000127   |
# |    value_loss           | 122         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 528          |
# |    ep_rew_mean          | 22.4         |
# | time/                   |              |
# |    fps                  | 1055         |
# |    iterations           | 20           |
# |    time_elapsed         | 310          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0056397514 |
# |    clip_fraction        | 0.0253       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.799        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 88.3         |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 218          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 574          |
# |    ep_rew_mean          | 32.4         |
# | time/                   |              |
# |    fps                  | 1039         |
# |    iterations           | 21           |
# |    time_elapsed         | 330          |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0073151095 |
# |    clip_fraction        | 0.0369       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.788        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57.2         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 191          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 578          |
# |    ep_rew_mean          | 27.4         |
# | time/                   |              |
# |    fps                  | 1021         |
# |    iterations           | 22           |
# |    time_elapsed         | 352          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0037375742 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.883        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.1         |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00171     |
# |    value_loss           | 94.6         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 659        |
# |    ep_rew_mean          | 42.8       |
# | time/                   |            |
# |    fps                  | 1008       |
# |    iterations           | 23         |
# |    time_elapsed         | 373        |
# |    total_timesteps      | 376832     |
# | train/                  |            |
# |    approx_kl            | 0.00526843 |
# |    clip_fraction        | 0.0462     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.14      |
# |    explained_variance   | 0.746      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 262        |
# |    n_updates            | 88         |
# |    policy_gradient_loss | -0.00144   |
# |    value_loss           | 226        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 705         |
# |    ep_rew_mean          | 56.9        |
# | time/                   |             |
# |    fps                  | 992         |
# |    iterations           | 24          |
# |    time_elapsed         | 396         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.004927165 |
# |    clip_fraction        | 0.032       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.1        |
# |    n_updates            | 92          |
# |    policy_gradient_loss | -0.00077    |
# |    value_loss           | 66.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 758          |
# |    ep_rew_mean          | 67.7         |
# | time/                   |              |
# |    fps                  | 977          |
# |    iterations           | 25           |
# |    time_elapsed         | 419          |
# |    total_timesteps      | 409600       |
# | train/                  |              |
# |    approx_kl            | 0.0053608133 |
# |    clip_fraction        | 0.0604       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.907        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.3         |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00232     |
# |    value_loss           | 71.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 767         |
# |    ep_rew_mean          | 70.2        |
# | time/                   |             |
# |    fps                  | 969         |
# |    iterations           | 26          |
# |    time_elapsed         | 439         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.002888423 |
# |    clip_fraction        | 0.032       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.8        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00142    |
# |    value_loss           | 151         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 791         |
# |    ep_rew_mean          | 85.7        |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 27          |
# |    time_elapsed         | 461         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.004022624 |
# |    clip_fraction        | 0.0256      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.1        |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.00132    |
# |    value_loss           | 92.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 799          |
# |    ep_rew_mean          | 90.3         |
# | time/                   |              |
# |    fps                  | 949          |
# |    iterations           | 28           |
# |    time_elapsed         | 482          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0063940585 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.937        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.5         |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.000394    |
# |    value_loss           | 62.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 822          |
# |    ep_rew_mean          | 92.9         |
# | time/                   |              |
# |    fps                  | 941          |
# |    iterations           | 29           |
# |    time_elapsed         | 504          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0060022734 |
# |    clip_fraction        | 0.0472       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.937        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.8         |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 50.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 824         |
# |    ep_rew_mean          | 95.4        |
# | time/                   |             |
# |    fps                  | 932         |
# |    iterations           | 30          |
# |    time_elapsed         | 527         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.008044943 |
# |    clip_fraction        | 0.0483      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80.9        |
# |    n_updates            | 116         |
# |    policy_gradient_loss | -0.00175    |
# |    value_loss           | 51.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 856          |
# |    ep_rew_mean          | 99           |
# | time/                   |              |
# |    fps                  | 926          |
# |    iterations           | 31           |
# |    time_elapsed         | 548          |
# |    total_timesteps      | 507904       |
# | train/                  |              |
# |    approx_kl            | 0.0054682386 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.29         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 32.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 890          |
# |    ep_rew_mean          | 102          |
# | time/                   |              |
# |    fps                  | 918          |
# |    iterations           | 32           |
# |    time_elapsed         | 570          |
# |    total_timesteps      | 524288       |
# | train/                  |              |
# |    approx_kl            | 0.0032339601 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.959        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.74         |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.000721    |
# |    value_loss           | 38           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 879          |
# |    ep_rew_mean          | 101          |
# | time/                   |              |
# |    fps                  | 911          |
# |    iterations           | 33           |
# |    time_elapsed         | 593          |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0049450714 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.938        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.02         |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.000892    |
# |    value_loss           | 57.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 893         |
# |    ep_rew_mean          | 106         |
# | time/                   |             |
# |    fps                  | 905         |
# |    iterations           | 34          |
# |    time_elapsed         | 615         |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.003929669 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.8        |
# |    n_updates            | 132         |
# |    policy_gradient_loss | -0.00181    |
# |    value_loss           | 73.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 109          |
# | time/                   |              |
# |    fps                  | 897          |
# |    iterations           | 35           |
# |    time_elapsed         | 639          |
# |    total_timesteps      | 573440       |
# | train/                  |              |
# |    approx_kl            | 0.0049093114 |
# |    clip_fraction        | 0.05         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.18         |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 11.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 915         |
# |    ep_rew_mean          | 112         |
# | time/                   |             |
# |    fps                  | 890         |
# |    iterations           | 36          |
# |    time_elapsed         | 662         |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.003252261 |
# |    clip_fraction        | 0.0344      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.1        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000979   |
# |    value_loss           | 21.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 939          |
# |    ep_rew_mean          | 119          |
# | time/                   |              |
# |    fps                  | 886          |
# |    iterations           | 37           |
# |    time_elapsed         | 683          |
# |    total_timesteps      | 606208       |
# | train/                  |              |
# |    approx_kl            | 0.0040979404 |
# |    clip_fraction        | 0.0436       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.32         |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.000899    |
# |    value_loss           | 9.21         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 942         |
# |    ep_rew_mean          | 120         |
# | time/                   |             |
# |    fps                  | 880         |
# |    iterations           | 38          |
# |    time_elapsed         | 707         |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.005678457 |
# |    clip_fraction        | 0.034       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3           |
# |    n_updates            | 148         |
# |    policy_gradient_loss | -0.00145    |
# |    value_loss           | 7.32        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 979          |
# |    ep_rew_mean          | 129          |
# | time/                   |              |
# |    fps                  | 875          |
# |    iterations           | 39           |
# |    time_elapsed         | 730          |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 0.0021887624 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.04         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -0.000499    |
# |    value_loss           | 18.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 978         |
# |    ep_rew_mean          | 131         |
# | time/                   |             |
# |    fps                  | 872         |
# |    iterations           | 40          |
# |    time_elapsed         | 751         |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.004487614 |
# |    clip_fraction        | 0.0327      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.992      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.91        |
# |    n_updates            | 156         |
# |    policy_gradient_loss | -0.000615   |
# |    value_loss           | 6.78        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 978          |
# |    ep_rew_mean          | 133          |
# | time/                   |              |
# |    fps                  | 868          |
# |    iterations           | 41           |
# |    time_elapsed         | 773          |
# |    total_timesteps      | 671744       |
# | train/                  |              |
# |    approx_kl            | 0.0058293343 |
# |    clip_fraction        | 0.0589       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.79         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 21.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 978          |
# |    ep_rew_mean          | 137          |
# | time/                   |              |
# |    fps                  | 865          |
# |    iterations           | 42           |
# |    time_elapsed         | 795          |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0036103623 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.49         |
# |    n_updates            | 164          |
# |    policy_gradient_loss | -1.28e-05    |
# |    value_loss           | 15.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 971         |
# |    ep_rew_mean          | 139         |
# | time/                   |             |
# |    fps                  | 863         |
# |    iterations           | 43          |
# |    time_elapsed         | 815         |
# |    total_timesteps      | 704512      |
# | train/                  |             |
# |    approx_kl            | 0.008501752 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.987      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.1         |
# |    n_updates            | 168         |
# |    policy_gradient_loss | -0.0022     |
# |    value_loss           | 5.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 971         |
# |    ep_rew_mean          | 143         |
# | time/                   |             |
# |    fps                  | 862         |
# |    iterations           | 44          |
# |    time_elapsed         | 835         |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.004512881 |
# |    clip_fraction        | 0.034       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.987      |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.59        |
# |    n_updates            | 172         |
# |    policy_gradient_loss | -0.000171   |
# |    value_loss           | 15.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 948          |
# |    ep_rew_mean          | 141          |
# | time/                   |              |
# |    fps                  | 860          |
# |    iterations           | 45           |
# |    time_elapsed         | 856          |
# |    total_timesteps      | 737280       |
# | train/                  |              |
# |    approx_kl            | 0.0031333137 |
# |    clip_fraction        | 0.0334       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.985       |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.7         |
# |    n_updates            | 176          |
# |    policy_gradient_loss | 0.000119     |
# |    value_loss           | 13.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 940          |
# |    ep_rew_mean          | 141          |
# | time/                   |              |
# |    fps                  | 859          |
# |    iterations           | 46           |
# |    time_elapsed         | 876          |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0033436888 |
# |    clip_fraction        | 0.0257       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.991       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.8         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | 0.000593     |
# |    value_loss           | 35.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 933          |
# |    ep_rew_mean          | 142          |
# | time/                   |              |
# |    fps                  | 858          |
# |    iterations           | 47           |
# |    time_elapsed         | 897          |
# |    total_timesteps      | 770048       |
# | train/                  |              |
# |    approx_kl            | 0.0068336315 |
# |    clip_fraction        | 0.0377       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.97        |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.2         |
# |    n_updates            | 184          |
# |    policy_gradient_loss | -0.00116     |
# |    value_loss           | 35.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 919          |
# |    ep_rew_mean          | 138          |
# | time/                   |              |
# |    fps                  | 856          |
# |    iterations           | 48           |
# |    time_elapsed         | 917          |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0035665482 |
# |    clip_fraction        | 0.0318       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.953       |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.9         |
# |    n_updates            | 188          |
# |    policy_gradient_loss | 7.12e-05     |
# |    value_loss           | 14.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 912          |
# |    ep_rew_mean          | 136          |
# | time/                   |              |
# |    fps                  | 855          |
# |    iterations           | 49           |
# |    time_elapsed         | 938          |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0063874675 |
# |    clip_fraction        | 0.0389       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.933       |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.51         |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 31.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 926          |
# |    ep_rew_mean          | 138          |
# | time/                   |              |
# |    fps                  | 853          |
# |    iterations           | 50           |
# |    time_elapsed         | 959          |
# |    total_timesteps      | 819200       |
# | train/                  |              |
# |    approx_kl            | 0.0035844205 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.908       |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.7         |
# |    n_updates            | 196          |
# |    policy_gradient_loss | 0.000384     |
# |    value_loss           | 25.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 955         |
# |    ep_rew_mean          | 144         |
# | time/                   |             |
# |    fps                  | 851         |
# |    iterations           | 51          |
# |    time_elapsed         | 980         |
# |    total_timesteps      | 835584      |
# | train/                  |             |
# |    approx_kl            | 0.004637594 |
# |    clip_fraction        | 0.0438      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.885      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.18        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -8.52e-05   |
# |    value_loss           | 2.72        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 962          |
# |    ep_rew_mean          | 146          |
# | time/                   |              |
# |    fps                  | 851          |
# |    iterations           | 52           |
# |    time_elapsed         | 1001         |
# |    total_timesteps      | 851968       |
# | train/                  |              |
# |    approx_kl            | 0.0036535303 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.891       |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.766        |
# |    n_updates            | 204          |
# |    policy_gradient_loss | 0.000112     |
# |    value_loss           | 24.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 962          |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 850          |
# |    iterations           | 53           |
# |    time_elapsed         | 1020         |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0051205917 |
# |    clip_fraction        | 0.0452       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.88        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25         |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.000961    |
# |    value_loss           | 2.14         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 954         |
# |    ep_rew_mean          | 145         |
# | time/                   |             |
# |    fps                  | 848         |
# |    iterations           | 54          |
# |    time_elapsed         | 1042        |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.003959988 |
# |    clip_fraction        | 0.0324      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.916      |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.64        |
# |    n_updates            | 212         |
# |    policy_gradient_loss | -0.00077    |
# |    value_loss           | 13.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 946          |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 849          |
# |    iterations           | 55           |
# |    time_elapsed         | 1061         |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# |    approx_kl            | 0.0057306904 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.888       |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.41         |
# |    n_updates            | 216          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 35.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 946          |
# |    ep_rew_mean          | 146          |
# | time/                   |              |
# |    fps                  | 848          |
# |    iterations           | 56           |
# |    time_elapsed         | 1080         |
# |    total_timesteps      | 917504       |
# | train/                  |              |
# |    approx_kl            | 0.0035700263 |
# |    clip_fraction        | 0.0444       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.878       |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.7         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00156     |
# |    value_loss           | 59           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 940          |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 848          |
# |    iterations           | 57           |
# |    time_elapsed         | 1100         |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0032927308 |
# |    clip_fraction        | 0.0538       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.85        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.933        |
# |    n_updates            | 224          |
# |    policy_gradient_loss | 0.000282     |
# |    value_loss           | 4.67         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 934          |
# |    ep_rew_mean          | 146          |
# | time/                   |              |
# |    fps                  | 847          |
# |    iterations           | 58           |
# |    time_elapsed         | 1121         |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0028574974 |
# |    clip_fraction        | 0.0466       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.865       |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.817        |
# |    n_updates            | 228          |
# |    policy_gradient_loss | 0.000538     |
# |    value_loss           | 15.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 934          |
# |    ep_rew_mean          | 147          |
# | time/                   |              |
# |    fps                  | 847          |
# |    iterations           | 59           |
# |    time_elapsed         | 1140         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0038160325 |
# |    clip_fraction        | 0.0287       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.857       |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.571        |
# |    n_updates            | 232          |
# |    policy_gradient_loss | -0.000162    |
# |    value_loss           | 34.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 949          |
# |    ep_rew_mean          | 151          |
# | time/                   |              |
# |    fps                  | 848          |
# |    iterations           | 60           |
# |    time_elapsed         | 1158         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0027072714 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.844       |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.917        |
# |    n_updates            | 236          |
# |    policy_gradient_loss | 0.000649     |
# |    value_loss           | 2.08         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 949         |
# |    ep_rew_mean          | 152         |
# | time/                   |             |
# |    fps                  | 848         |
# |    iterations           | 61          |
# |    time_elapsed         | 1178        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.003853932 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.86       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.26        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -6.33e-05   |
# |    value_loss           | 21.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 942          |
# |    ep_rew_mean          | 151          |
# | time/                   |              |
# |    fps                  | 848          |
# |    iterations           | 62           |
# |    time_elapsed         | 1196         |
# |    total_timesteps      | 1015808      |
# | train/                  |              |
# |    approx_kl            | 0.0033282908 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.841       |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.1         |
# |    n_updates            | 244          |
# |    policy_gradient_loss | 0.00027      |
# |    value_loss           | 29.2         |
# ------------------------------------------

# %%
eval_env = gym.make("LunarLander-v2")
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward=264.79 +/- 17.613661536595654

# %%
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

from huggingface_sb3 import package_to_hub

# PLACE the variables you've just defined two cells above
# Define the name of the environment
env_id = "LunarLander-v2"

# TODO: Define the model architecture we used
model_architecture = "PPO"

## Define a repo_id
## repo_id is the id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
## CHANGE WITH YOUR REPO ID
repo_id = "ThomasSimonini/ppo-LunarLander-v2" # Change with your repo id, you can't push with mine 😄

## Define the commit message
commit_message = "Upload PPO LunarLander-v2 trained agent"

# Create the evaluation env and set the render_mode="rgb_array"
eval_env = DummyVecEnv([lambda: gym.make(env_id, render_mode="rgb_array")])

# PLACE the package_to_hub function you've just filled here
package_to_hub(model=model, # Our trained model
               model_name=model_name, # The name of our trained model 
               model_architecture=model_architecture, # The model architecture we used: in our case PPO
               env_id=env_id, # Name of the environment
               eval_env=eval_env, # Evaluation Environment
               repo_id=repo_id, # id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
               commit_message=commit_message)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-9ef2f67f4067> in <cell line: 28>()
#      26
#      27 # PLACE the package_to_hub function you've just filled here
# ---> 28 package_to_hub(model=model, # Our trained model
#      29                model_name=model_name, # The name of our trained model
#      30                model_architecture=model_architecture, # The model architecture we used: in our case PPO
#
# /usr/local/lib/python3.10/dist-packages/huggingface_sb3/push_to_hub.py in package_to_hub(model, model_name, model_architecture, env_id, eval_env, repo_id, commit_message, is_deterministic, n_eval_episodes, token, video_length, logs)
#     331     )
#     332
# --> 333     repo_url = HfApi().create_repo(
#     334         repo_id=repo_id,
#     335         token=token,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     118             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     119
# --> 120         return fn(*args, **kwargs)
#     121
#     122     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_api.py in create_repo(self, repo_id, token, private, repo_type, exist_ok, space_sdk, space_hardware)
#    2179             # See https://github.com/huggingface/huggingface_hub/pull/733/files#r820604472
#    2180             json["lfsmultipartthresh"] = self._lfsmultipartthresh  # type: ignore
# -> 2181         headers = self._build_hf_headers(token=token, is_write_action=True)
#    2182         r = get_session().post(path, headers=headers, json=json)
#    2183
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_api.py in _build_hf_headers(self, token, is_write_action, library_name, library_version, user_agent)
#    4730             # Cannot do `token = token or self.token` as token can be `False`.
#    4731             token = self.token
# -> 4732         return build_hf_headers(
#    4733             token=token,
#    4734             is_write_action=is_write_action,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     118             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     119
# --> 120         return fn(*args, **kwargs)
#     121
#     122     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_headers.py in build_hf_headers(token, is_write_action, library_name, library_version, user_agent)
#     116     # Get auth token to send
#     117     token_to_send = get_token_to_send(token)
# --> 118     _validate_token_to_send(token_to_send, is_write_action=is_write_action)
#     119
#     120     # Combine headers
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_headers.py in _validate_token_to_send(token, is_write_action)
#     166     if is_write_action:
#     167         if token is None:
# --> 168             raise ValueError(
#     169                 "Token is required (write-access action) but no token found. You need"
#     170                 " to provide a token or be logged in to Hugging Face with"
#
# ValueError: Token is required (write-access action) but no token found. You need to provide a token or be logged in to Hugging Face with `huggingface-cli login` or `huggingface_hub.login`. See https://huggingface.co/settings/tokens.

# %%
# !pip install shimmy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shimmy
#   Downloading Shimmy-1.0.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: gymnasium>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from shimmy) (0.28.1)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from shimmy) (1.22.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27.0->shimmy) (4.5.0)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27.0->shimmy) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27.0->shimmy) (2.2.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27.0->shimmy) (0.0.4)
# Installing collected packages: shimmy
# Successfully installed shimmy-1.0.0

# %%
from huggingface_sb3 import load_from_hub
repo_id = "Classroom-workshop/assignment2-omar" # The repo_id
filename = "ppo-LunarLander-v2.zip" # The model filename.zip

# When the model was trained on Python 3.8 the pickle protocol is 5
# But Python 3.6, 3.7 use protocol 4
# In order to get compatibility we need to:
# 1. Install pickle5 (we done it at the beginning of the colab)
# 2. Create a custom empty object we pass as parameter to PPO.load()
custom_objects = {
            "learning_rate": 0.0,
            "lr_schedule": lambda _: 0.0,
            "clip_range": lambda _: 0.0,
}

checkpoint = load_from_hub(repo_id, filename)
model = PPO.load(checkpoint, custom_objects=custom_objects, print_system_info=True)
# Out:
# Downloading ppo-LunarLander-v2.zip:   0%|          | 0.00/146k [00:00<?, ?B/s]
# == CURRENT SYSTEM INFO ==
# - OS: Linux-5.10.147+-x86_64-with-glibc2.31 # 1 SMP Sat Dec 10 16:00:40 UTC 2022
# - Python: 3.10.11
# - Stable-Baselines3: 2.0.0a5
# - PyTorch: 2.0.0+cu118
# - GPU Enabled: True
# - Numpy: 1.22.4
# - Cloudpickle: 2.2.1
# - Gymnasium: 0.28.1
# - OpenAI Gym: 0.25.2
#
# == SAVED MODEL SYSTEM INFO ==
# OS: Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic #1 SMP Sun Apr 24 10:03:06 PDT 2022
# Python: 3.7.13
# Stable-Baselines3: 1.5.0
# PyTorch: 1.11.0+cu113
# GPU Enabled: True
# Numpy: 1.21.6
# Gym: 0.21.0
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:95: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   warnings.warn(

# %%
eval_env = gym.make("LunarLander-v2")
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=300.49 +/- 10.87992380783169
